# %% [markdown]
# <a href="https://colab.research.google.com/github/IKosovych/ucu-recommender-system-2023/blob/master/ContentBasedFiltering_and_BaseLine_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.model_selection import train_test_split
from sklearn.metrics import ndcg_score
from sklearn.preprocessing import LabelBinarizer
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# After inspection of four datases I didn't found severe outliers that can cause problems in our tasks.

# %% [markdown]
# ###Content-Based Filtering model implementation

# %%
class ContentBasedFiltering:
    """
    A content-based filtering algorithm based on movie genres
    """

    def __init__(self, train_size=0.8):
        self.df_movies = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/ml-latest-small/movies.csv')
        self.df_ratings = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/ml-latest-small/ratings.csv')
        self.df_movies['genres'] = self.df_movies['genres'].fillna('')
        self.indices = pd.Series(self.df_movies.index, index=self.df_movies['movieId']).drop_duplicates()
        self.train_size = train_size
        self.train_set, self.test_set = self.train_test_split()

    def train_test_split(self):
        train, test = train_test_split(self.df_ratings, test_size=1-self.train_size, random_state=42, stratify=self.df_ratings['userId'])
        return train, test

    def fit(self):
        # Use TF-IDF to convert the genres into vectors
        tfidf = TfidfVectorizer(stop_words='english')
        tfidf_matrix = tfidf.fit_transform(self.df_movies['genres'])

        # Compute the cosine similarity matrix
        self.cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

    def predict_on_testset(self, user_id):
        # Get the movies that the user has watched
        watched_movies = self.train_set[self.train_set['userId'] == user_id]['movieId'].tolist()

        # Get the pairwise similarity scores of all movies with each movie the user has watched
        sim_scores = [list(enumerate(self.cosine_sim[self.indices[movie]])) for movie in watched_movies]

        # Flatten the list and sort it based on the similarity scores
        sim_scores = sorted([score for sublist in sim_scores for score in sublist], key=lambda x: x[1], reverse=True)

        # Get the scores of the 10 most similar movies
        sim_scores = sim_scores[1:11]

        # Get the movie indices
        movie_indices = [i[0] for i in sim_scores]

        # Return the top 10 most similar movies
        return self.df_movies['title'].iloc[movie_indices]

    def evaluate(self):
        users = self.test_set['userId'].unique()
        average_ndcg = []

        for user in users:
            actual = self.test_set[self.test_set['userId'] == user]['movieId'].tolist()
            predicted = self.predict_on_testset(user)

            # Convert movie titles back to ids for evaluation
            predicted_ids = self.df_movies[self.df_movies['title'].isin(predicted)]['movieId'].tolist()

            lb = LabelBinarizer()
            lb.fit(actual)

            if len(predicted_ids) <= len(actual):
                actual = actual[:len(predicted_ids)]
            else:
                predicted_ids = predicted_ids[:len(actual)]

            binary_actual = lb.transform(actual)
            binary_predicted = lb.transform(predicted_ids)

            average_ndcg.append(ndcg_score(binary_actual, binary_predicted))

        return np.mean(average_ndcg)

# %%
cbf = ContentBasedFiltering()
cbf.fit()

recommendations = cbf.predict_on_testset(2)

print("Recommendations for User {}:".format(2))
for idx, title in enumerate(recommendations):
    print("{}: {}".format(idx+1, title))
# Out:
# Recommendations for User 2:
# 1: Apocalypse Now (1979)
# 2: Boot, Das (Boat, The) (1981)
# 3: All Quiet on the Western Front (1930)
# 4: Saving Private Ryan (1998)
# 5: Thin Red Line, The (1998)
# 6: Dirty Dozen, The (1967)
# 7: Longest Day, The (1962)
# 8: Tora! Tora! Tora! (1970)
# 9: Red Dawn (1984)
# 10: Force 10 from Navarone (1978)

# %% [markdown]
# ###Content-Based Filtering model Evaluation

# %%
average_ndcg = cbf.evaluate()
print(f'Average NDCG: {average_ndcg}')
# Out:
# Average NDCG: 0.40424739400007437

# %% [markdown]
# ###Baseline model implementation

# %%
from sklearn.model_selection import train_test_split

class BaselineModel:
    """
    A baseline recommendation model that recommends movies
    based on their popularity and average ratings
    """
    def __init__(self, train_size=0.8):
        self.df_links = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/ml-latest-small/links.csv')
        self.df_tags = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/ml-latest-small/tags.csv')
        self.df_ratings = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/ml-latest-small/ratings.csv')
        self.df_movies = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/ml-latest-small/movies.csv')
        self.train_size = train_size
        self.train_set, self.test_set = self.train_test_split()

    def train_test_split(self):
        train, test = train_test_split(self.df_ratings, test_size=1-self.train_size, random_state=42, stratify=self.df_ratings['userId'])
        return train, test

    def fit(self):
        self.train_set['count'] = 1
        df_ratings_aggr = self.train_set.groupby('movieId')[['rating', 'count']].sum()
        df_ratings_aggr['rating_avg'] = round(df_ratings_aggr['rating'] / df_ratings_aggr['count'],1)
        df_ratings_aggr['rank'] = np.log(df_ratings_aggr['rating']) * df_ratings_aggr['rating_avg']

        self.df_ranked_films = pd.merge(self.df_movies, df_ratings_aggr[['rank', 'rating_avg']], on='movieId', how='outer') \
            .sort_values(by=['rank'], ascending=False) \
            .fillna(0)

    def predict_on_testset(self, user_id):
        filtered_films = self.df_ranked_films.merge(self.train_set[self.train_set['userId'] == user_id]['movieId'],
                                                     on='movieId',
                                                     how='left',
                                                     indicator=True)

        filtered_films = filtered_films[filtered_films['_merge'] == 'left_only']
        return filtered_films[['movieId', 'title', 'rank']].head(10)

# %%
bm = BaselineModel()
bm.fit()
print(bm.predict_on_testset(1)) # Assuming 1 is a valid user_id
# Out:
#     movieId                                              title       rank
# 0       318                   Shawshank Redemption, The (1994)  31.437469
# 1       296                                Pulp Fiction (1994)  29.331918
# 7       858                              Godfather, The (1972)  28.029161
# 13    58559                            Dark Knight, The (2008)  26.887327
# 14      110                                  Braveheart (1995)  26.608871
# 15     5952      Lord of the Rings: The Two Towers, The (2002)  26.599504
# 17     7153  Lord of the Rings: The Return of the King, The...  26.552432
# 19     1193             One Flew Over the Cuckoo's Nest (1975)  26.515811
# 20     4993  Lord of the Rings: The Fellowship of the Ring,...  26.511193
# 22      589                  Terminator 2: Judgment Day (1991)  26.210032

# %% [markdown]
# ###BaseLine model evaluation

# %%
from typing import List
from sklearn.metrics import f1_score

model = BaselineModel()
model.fit()

from sklearn.metrics import f1_score

def precision_at_k(predicted: List[int], actual: List[int], k: int) -> float:
    assert k <= len(predicted)
    return len(set(predicted[:k]) & set(actual)) / k

def recall_at_k(predicted: List[int], actual: List[int], k: int) -> float:
    assert k <= len(predicted)
    return len(set(predicted[:k]) & set(actual)) / len(set(actual))

def f1_at_k(predicted: List[int], actual: List[int], k: int) -> float:
    precision = precision_at_k(predicted, actual, k)
    recall = recall_at_k(predicted, actual, k)
    return 2 * (precision * recall) / (precision + recall) if precision + recall > 0 else 0
# For each user in the test set, generate the top-N predictions and evaluate them
for user_id in model.test_set['userId'].unique():
    actual_movies = model.test_set[model.test_set['userId'] == user_id]['movieId'].tolist()
    predicted_movies = model.predict_on_testset(user_id)['movieId'].tolist()

    precision = precision_at_k(predicted_movies, actual_movies, k=10)
    recall = recall_at_k(predicted_movies, actual_movies, k=10)
    f1 = f1_at_k(predicted_movies, actual_movies, k=10)

    print(f'User ID: {user_id}, Precision@10: {precision:.2f}, Recall@10: {recall:.2f}, F1@10: {f1:.2f}')
# Out:
# User ID: 318, Precision@10: 0.40, Recall@10: 0.02, F1@10: 0.04
# User ID: 288, Precision@10: 0.40, Recall@10: 0.02, F1@10: 0.04
# User ID: 314, Precision@10: 0.20, Recall@10: 0.08, F1@10: 0.11
# User ID: 184, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 414, Precision@10: 1.00, Recall@10: 0.02, F1@10: 0.04
# User ID: 182, Precision@10: 0.60, Recall@10: 0.03, F1@10: 0.06
# User ID: 126, Precision@10: 0.20, Recall@10: 0.25, F1@10: 0.22
# User ID: 462, Precision@10: 0.20, Recall@10: 0.02, F1@10: 0.04
# User ID: 483, Precision@10: 0.60, Recall@10: 0.04, F1@10: 0.08
# User ID: 234, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 63, Precision@10: 0.70, Recall@10: 0.13, F1@10: 0.22
# User ID: 387, Precision@10: 0.50, Recall@10: 0.02, F1@10: 0.05
# User ID: 176, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 28, Precision@10: 0.90, Recall@10: 0.08, F1@10: 0.15
# User ID: 607, Precision@10: 0.20, Recall@10: 0.05, F1@10: 0.09
# User ID: 367, Precision@10: 0.20, Recall@10: 0.05, F1@10: 0.09
# User ID: 298, Precision@10: 0.70, Recall@10: 0.04, F1@10: 0.07
# User ID: 198, Precision@10: 0.20, Recall@10: 0.04, F1@10: 0.07
# User ID: 593, Precision@10: 0.30, Recall@10: 0.14, F1@10: 0.19
# User ID: 517, Precision@10: 0.10, Recall@10: 0.01, F1@10: 0.02
# User ID: 399, Precision@10: 0.30, Recall@10: 0.43, F1@10: 0.35
# User ID: 66, Precision@10: 0.50, Recall@10: 0.07, F1@10: 0.13
# User ID: 381, Precision@10: 0.40, Recall@10: 0.04, F1@10: 0.08
# User ID: 84, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.03
# User ID: 294, Precision@10: 0.10, Recall@10: 0.01, F1@10: 0.02
# User ID: 429, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 104, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 174, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 357, Precision@10: 0.30, Recall@10: 0.04, F1@10: 0.07
# User ID: 599, Precision@10: 0.80, Recall@10: 0.02, F1@10: 0.03
# User ID: 199, Precision@10: 0.40, Recall@10: 0.05, F1@10: 0.10
# User ID: 592, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 610, Precision@10: 0.80, Recall@10: 0.03, F1@10: 0.06
# User ID: 200, Precision@10: 0.30, Recall@10: 0.04, F1@10: 0.08
# User ID: 279, Precision@10: 0.70, Recall@10: 0.20, F1@10: 0.31
# User ID: 603, Precision@10: 0.40, Recall@10: 0.02, F1@10: 0.04
# User ID: 560, Precision@10: 0.40, Recall@10: 0.04, F1@10: 0.08
# User ID: 8, Precision@10: 0.10, Recall@10: 0.11, F1@10: 0.11
# User ID: 382, Precision@10: 0.70, Recall@10: 0.12, F1@10: 0.21
# User ID: 177, Precision@10: 0.80, Recall@10: 0.04, F1@10: 0.08
# User ID: 448, Precision@10: 0.50, Recall@10: 0.01, F1@10: 0.03
# User ID: 527, Precision@10: 0.30, Recall@10: 0.09, F1@10: 0.14
# User ID: 600, Precision@10: 0.70, Recall@10: 0.05, F1@10: 0.09
# User ID: 135, Precision@10: 0.40, Recall@10: 0.07, F1@10: 0.12
# User ID: 20, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 140, Precision@10: 0.30, Recall@10: 0.02, F1@10: 0.05
# User ID: 572, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.05
# User ID: 103, Precision@10: 0.50, Recall@10: 0.07, F1@10: 0.12
# User ID: 232, Precision@10: 0.20, Recall@10: 0.01, F1@10: 0.02
# User ID: 575, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 262, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 68, Precision@10: 0.90, Recall@10: 0.04, F1@10: 0.07
# User ID: 406, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 597, Precision@10: 0.10, Recall@10: 0.01, F1@10: 0.02
# User ID: 4, Precision@10: 0.20, Recall@10: 0.05, F1@10: 0.08
# User ID: 256, Precision@10: 0.30, Recall@10: 0.09, F1@10: 0.13
# User ID: 195, Precision@10: 0.20, Recall@10: 0.05, F1@10: 0.09
# User ID: 141, Precision@10: 0.30, Recall@10: 0.09, F1@10: 0.14
# User ID: 62, Precision@10: 0.50, Recall@10: 0.07, F1@10: 0.12
# User ID: 460, Precision@10: 0.10, Recall@10: 0.06, F1@10: 0.08
# User ID: 225, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 595, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 19, Precision@10: 0.10, Recall@10: 0.01, F1@10: 0.01
# User ID: 495, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.03
# User ID: 286, Precision@10: 0.20, Recall@10: 0.10, F1@10: 0.13
# User ID: 143, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 532, Precision@10: 0.30, Recall@10: 0.30, F1@10: 0.30
# User ID: 119, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.04
# User ID: 57, Precision@10: 0.40, Recall@10: 0.04, F1@10: 0.08
# User ID: 305, Precision@10: 0.50, Recall@10: 0.04, F1@10: 0.07
# User ID: 605, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 105, Precision@10: 0.30, Recall@10: 0.02, F1@10: 0.04
# User ID: 212, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.03
# User ID: 463, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 477, Precision@10: 0.40, Recall@10: 0.03, F1@10: 0.06
# User ID: 229, Precision@10: 0.20, Recall@10: 0.15, F1@10: 0.17
# User ID: 217, Precision@10: 0.20, Recall@10: 0.02, F1@10: 0.03
# User ID: 47, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 342, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 83, Precision@10: 0.10, Recall@10: 0.04, F1@10: 0.06
# User ID: 158, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 123, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 125, Precision@10: 0.20, Recall@10: 0.03, F1@10: 0.05
# User ID: 91, Precision@10: 0.50, Recall@10: 0.04, F1@10: 0.08
# User ID: 492, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 489, Precision@10: 0.20, Recall@10: 0.02, F1@10: 0.03
# User ID: 474, Precision@10: 0.70, Recall@10: 0.02, F1@10: 0.03
# User ID: 491, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 452, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.04
# User ID: 365, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.03
# User ID: 368, Precision@10: 0.30, Recall@10: 0.03, F1@10: 0.06
# User ID: 249, Precision@10: 0.70, Recall@10: 0.03, F1@10: 0.06
# User ID: 307, Precision@10: 0.60, Recall@10: 0.03, F1@10: 0.06
# User ID: 418, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.07
# User ID: 75, Precision@10: 0.10, Recall@10: 0.07, F1@10: 0.08
# User ID: 564, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.05
# User ID: 226, Precision@10: 0.20, Recall@10: 0.02, F1@10: 0.04
# User ID: 596, Precision@10: 0.40, Recall@10: 0.05, F1@10: 0.09
# User ID: 202, Precision@10: 0.40, Recall@10: 0.05, F1@10: 0.09
# User ID: 334, Precision@10: 0.30, Recall@10: 0.10, F1@10: 0.15
# User ID: 74, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.04
# User ID: 106, Precision@10: 0.20, Recall@10: 0.29, F1@10: 0.24
# User ID: 70, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 88, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 335, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 325, Precision@10: 0.20, Recall@10: 0.04, F1@10: 0.06
# User ID: 425, Precision@10: 0.70, Recall@10: 0.11, F1@10: 0.20
# User ID: 246, Precision@10: 0.20, Recall@10: 0.05, F1@10: 0.08
# User ID: 160, Precision@10: 0.60, Recall@10: 0.07, F1@10: 0.12
# User ID: 561, Precision@10: 0.60, Recall@10: 0.06, F1@10: 0.11
# User ID: 330, Precision@10: 0.80, Recall@10: 0.16, F1@10: 0.27
# User ID: 587, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.05
# User ID: 339, Precision@10: 0.40, Recall@10: 0.05, F1@10: 0.10
# User ID: 254, Precision@10: 0.50, Recall@10: 0.20, F1@10: 0.29
# User ID: 424, Precision@10: 0.10, Recall@10: 0.04, F1@10: 0.05
# User ID: 567, Precision@10: 0.10, Recall@10: 0.01, F1@10: 0.02
# User ID: 410, Precision@10: 0.30, Recall@10: 0.09, F1@10: 0.14
# User ID: 45, Precision@10: 0.60, Recall@10: 0.07, F1@10: 0.13
# User ID: 417, Precision@10: 0.20, Recall@10: 0.15, F1@10: 0.17
# User ID: 544, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 328, Precision@10: 0.40, Recall@10: 0.08, F1@10: 0.13
# User ID: 156, Precision@10: 0.30, Recall@10: 0.04, F1@10: 0.07
# User ID: 566, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 109, Precision@10: 0.30, Recall@10: 0.12, F1@10: 0.17
# User ID: 458, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 555, Precision@10: 0.30, Recall@10: 0.03, F1@10: 0.05
# User ID: 216, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 524, Precision@10: 0.20, Recall@10: 0.08, F1@10: 0.11
# User ID: 6, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.03
# User ID: 313, Precision@10: 0.40, Recall@10: 0.06, F1@10: 0.10
# User ID: 292, Precision@10: 0.30, Recall@10: 0.03, F1@10: 0.06
# User ID: 539, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 23, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 380, Precision@10: 0.40, Recall@10: 0.02, F1@10: 0.03
# User ID: 228, Precision@10: 0.30, Recall@10: 0.60, F1@10: 0.40
# User ID: 488, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 563, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 43, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 395, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 570, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.04
# User ID: 317, Precision@10: 0.30, Recall@10: 0.08, F1@10: 0.12
# User ID: 167, Precision@10: 0.20, Recall@10: 0.06, F1@10: 0.09
# User ID: 590, Precision@10: 0.80, Recall@10: 0.05, F1@10: 0.10
# User ID: 152, Precision@10: 0.30, Recall@10: 0.23, F1@10: 0.26
# User ID: 315, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 111, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 351, Precision@10: 0.20, Recall@10: 0.07, F1@10: 0.11
# User ID: 606, Precision@10: 0.60, Recall@10: 0.03, F1@10: 0.05
# User ID: 186, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 432, Precision@10: 0.60, Recall@10: 0.12, F1@10: 0.19
# User ID: 404, Precision@10: 0.10, Recall@10: 0.08, F1@10: 0.09
# User ID: 24, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.06
# User ID: 201, Precision@10: 0.30, Recall@10: 0.14, F1@10: 0.19
# User ID: 18, Precision@10: 0.70, Recall@10: 0.07, F1@10: 0.13
# User ID: 344, Precision@10: 0.10, Recall@10: 0.07, F1@10: 0.08
# User ID: 371, Precision@10: 0.10, Recall@10: 0.12, F1@10: 0.11
# User ID: 21, Precision@10: 0.20, Recall@10: 0.02, F1@10: 0.04
# User ID: 122, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.03
# User ID: 275, Precision@10: 0.40, Recall@10: 0.05, F1@10: 0.09
# User ID: 115, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.06
# User ID: 510, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.06
# User ID: 51, Precision@10: 0.10, Recall@10: 0.01, F1@10: 0.02
# User ID: 64, Precision@10: 0.50, Recall@10: 0.05, F1@10: 0.09
# User ID: 438, Precision@10: 0.10, Recall@10: 0.01, F1@10: 0.01
# User ID: 219, Precision@10: 0.30, Recall@10: 0.03, F1@10: 0.05
# User ID: 534, Precision@10: 0.10, Recall@10: 0.01, F1@10: 0.02
# User ID: 356, Precision@10: 0.30, Recall@10: 0.05, F1@10: 0.09
# User ID: 222, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.03
# User ID: 1, Precision@10: 0.20, Recall@10: 0.04, F1@10: 0.07
# User ID: 154, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 113, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.05
# User ID: 419, Precision@10: 0.30, Recall@10: 0.10, F1@10: 0.15
# User ID: 514, Precision@10: 0.50, Recall@10: 0.06, F1@10: 0.11
# User ID: 264, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 420, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 369, Precision@10: 0.10, Recall@10: 0.04, F1@10: 0.06
# User ID: 274, Precision@10: 0.90, Recall@10: 0.03, F1@10: 0.06
# User ID: 470, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 166, Precision@10: 0.40, Recall@10: 0.11, F1@10: 0.17
# User ID: 553, Precision@10: 0.10, Recall@10: 0.06, F1@10: 0.07
# User ID: 10, Precision@10: 0.10, Recall@10: 0.04, F1@10: 0.05
# User ID: 260, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.05
# User ID: 89, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 516, Precision@10: 0.10, Recall@10: 0.20, F1@10: 0.13
# User ID: 50, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.03
# User ID: 323, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.07
# User ID: 221, Precision@10: 0.40, Recall@10: 0.06, F1@10: 0.11
# User ID: 151, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 178, Precision@10: 0.20, Recall@10: 0.13, F1@10: 0.16
# User ID: 224, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 480, Precision@10: 0.90, Recall@10: 0.05, F1@10: 0.10
# User ID: 608, Precision@10: 0.30, Recall@10: 0.02, F1@10: 0.03
# User ID: 117, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.05
# User ID: 582, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 451, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 268, Precision@10: 0.30, Recall@10: 0.12, F1@10: 0.17
# User ID: 248, Precision@10: 0.10, Recall@10: 0.10, F1@10: 0.10
# User ID: 22, Precision@10: 0.20, Recall@10: 0.08, F1@10: 0.12
# User ID: 586, Precision@10: 0.40, Recall@10: 0.10, F1@10: 0.15
# User ID: 42, Precision@10: 0.30, Recall@10: 0.03, F1@10: 0.06
# User ID: 588, Precision@10: 0.20, Recall@10: 0.18, F1@10: 0.19
# User ID: 573, Precision@10: 0.60, Recall@10: 0.10, F1@10: 0.17
# User ID: 239, Precision@10: 0.50, Recall@10: 0.09, F1@10: 0.15
# User ID: 213, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 465, Precision@10: 0.20, Recall@10: 0.09, F1@10: 0.12
# User ID: 370, Precision@10: 0.30, Recall@10: 0.16, F1@10: 0.21
# User ID: 331, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.05
# User ID: 400, Precision@10: 0.20, Recall@10: 0.22, F1@10: 0.21
# User ID: 11, Precision@10: 0.10, Recall@10: 0.08, F1@10: 0.09
# User ID: 309, Precision@10: 0.30, Recall@10: 0.14, F1@10: 0.19
# User ID: 469, Precision@10: 0.40, Recall@10: 0.04, F1@10: 0.08
# User ID: 449, Precision@10: 0.10, Recall@10: 0.12, F1@10: 0.11
# User ID: 16, Precision@10: 0.40, Recall@10: 0.20, F1@10: 0.27
# User ID: 346, Precision@10: 0.20, Recall@10: 0.06, F1@10: 0.09
# User ID: 191, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 525, Precision@10: 0.40, Recall@10: 0.04, F1@10: 0.07
# User ID: 391, Precision@10: 0.60, Recall@10: 0.08, F1@10: 0.14
# User ID: 100, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 12, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 129, Precision@10: 0.20, Recall@10: 0.07, F1@10: 0.11
# User ID: 546, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 169, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.03
# User ID: 583, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 522, Precision@10: 0.60, Recall@10: 0.15, F1@10: 0.24
# User ID: 185, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 98, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 437, Precision@10: 0.20, Recall@10: 0.08, F1@10: 0.12
# User ID: 326, Precision@10: 0.30, Recall@10: 0.10, F1@10: 0.15
# User ID: 148, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 580, Precision@10: 0.50, Recall@10: 0.06, F1@10: 0.10
# User ID: 372, Precision@10: 0.30, Recall@10: 0.06, F1@10: 0.11
# User ID: 521, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 385, Precision@10: 0.30, Recall@10: 0.07, F1@10: 0.12
# User ID: 479, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 211, Precision@10: 0.60, Recall@10: 0.33, F1@10: 0.43
# User ID: 259, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 363, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 378, Precision@10: 0.10, Recall@10: 0.10, F1@10: 0.10
# User ID: 132, Precision@10: 0.10, Recall@10: 0.01, F1@10: 0.03
# User ID: 332, Precision@10: 0.50, Recall@10: 0.09, F1@10: 0.16
# User ID: 146, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 475, Precision@10: 0.20, Recall@10: 0.06, F1@10: 0.10
# User ID: 464, Precision@10: 0.40, Recall@10: 0.14, F1@10: 0.21
# User ID: 591, Precision@10: 0.20, Recall@10: 0.18, F1@10: 0.19
# User ID: 52, Precision@10: 0.20, Recall@10: 0.08, F1@10: 0.11
# User ID: 27, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 554, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 25, Precision@10: 0.20, Recall@10: 0.40, F1@10: 0.27
# User ID: 408, Precision@10: 0.20, Recall@10: 0.07, F1@10: 0.11
# User ID: 547, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 551, Precision@10: 0.30, Recall@10: 0.12, F1@10: 0.17
# User ID: 7, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 509, Precision@10: 0.20, Recall@10: 0.02, F1@10: 0.04
# User ID: 427, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 31, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 336, Precision@10: 0.30, Recall@10: 0.27, F1@10: 0.29
# User ID: 17, Precision@10: 0.40, Recall@10: 0.19, F1@10: 0.26
# User ID: 557, Precision@10: 0.40, Recall@10: 0.80, F1@10: 0.53
# User ID: 490, Precision@10: 0.20, Recall@10: 0.09, F1@10: 0.12
# User ID: 82, Precision@10: 0.20, Recall@10: 0.04, F1@10: 0.07
# User ID: 306, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 54, Precision@10: 0.20, Recall@10: 0.29, F1@10: 0.24
# User ID: 536, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 459, Precision@10: 0.10, Recall@10: 0.20, F1@10: 0.13
# User ID: 508, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 41, Precision@10: 0.20, Recall@10: 0.05, F1@10: 0.08
# User ID: 504, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 466, Precision@10: 0.10, Recall@10: 0.04, F1@10: 0.06
# User ID: 287, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 267, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 604, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 270, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 215, Precision@10: 0.30, Recall@10: 0.15, F1@10: 0.20
# User ID: 440, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 562, Precision@10: 0.30, Recall@10: 0.07, F1@10: 0.11
# User ID: 500, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 187, Precision@10: 0.40, Recall@10: 0.08, F1@10: 0.13
# User ID: 255, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 348, Precision@10: 0.20, Recall@10: 0.18, F1@10: 0.19
# User ID: 95, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 252, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 401, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 241, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 257, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 139, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.04
# User ID: 284, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 197, Precision@10: 0.20, Recall@10: 0.29, F1@10: 0.24
# User ID: 528, Precision@10: 0.10, Recall@10: 0.07, F1@10: 0.08
# User ID: 392, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 209, Precision@10: 0.30, Recall@10: 0.43, F1@10: 0.35
# User ID: 32, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.07
# User ID: 422, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.07
# User ID: 388, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 428, Precision@10: 0.30, Recall@10: 0.05, F1@10: 0.09
# User ID: 153, Precision@10: 0.20, Recall@10: 0.06, F1@10: 0.09
# User ID: 290, Precision@10: 0.20, Recall@10: 0.04, F1@10: 0.06
# User ID: 482, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 415, Precision@10: 0.20, Recall@10: 0.11, F1@10: 0.14
# User ID: 58, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.06
# User ID: 266, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 512, Precision@10: 0.40, Recall@10: 0.40, F1@10: 0.40
# User ID: 411, Precision@10: 0.20, Recall@10: 0.08, F1@10: 0.11
# User ID: 354, Precision@10: 0.20, Recall@10: 0.04, F1@10: 0.07
# User ID: 361, Precision@10: 0.20, Recall@10: 0.11, F1@10: 0.14
# User ID: 304, Precision@10: 0.50, Recall@10: 0.12, F1@10: 0.19
# User ID: 96, Precision@10: 0.20, Recall@10: 0.12, F1@10: 0.15
# User ID: 577, Precision@10: 0.20, Recall@10: 0.06, F1@10: 0.10
# User ID: 73, Precision@10: 0.10, Recall@10: 0.02, F1@10: 0.04
# User ID: 412, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.07
# User ID: 538, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 454, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 473, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 434, Precision@10: 0.70, Recall@10: 0.15, F1@10: 0.25
# User ID: 130, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 29, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 280, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 179, Precision@10: 0.10, Recall@10: 0.07, F1@10: 0.08
# User ID: 594, Precision@10: 0.20, Recall@10: 0.04, F1@10: 0.07
# User ID: 92, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 107, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 206, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 312, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 134, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 503, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 190, Precision@10: 0.10, Recall@10: 0.08, F1@10: 0.09
# User ID: 210, Precision@10: 0.10, Recall@10: 0.04, F1@10: 0.05
# User ID: 235, Precision@10: 0.10, Recall@10: 0.08, F1@10: 0.09
# User ID: 405, Precision@10: 0.10, Recall@10: 0.04, F1@10: 0.06
# User ID: 240, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 341, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 359, Precision@10: 0.20, Recall@10: 0.13, F1@10: 0.16
# User ID: 578, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 601, Precision@10: 0.30, Recall@10: 0.15, F1@10: 0.20
# User ID: 350, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 443, Precision@10: 0.30, Recall@10: 0.43, F1@10: 0.35
# User ID: 223, Precision@10: 0.20, Recall@10: 0.13, F1@10: 0.16
# User ID: 14, Precision@10: 0.30, Recall@10: 0.30, F1@10: 0.30
# User ID: 484, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 13, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 316, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 543, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 327, Precision@10: 0.10, Recall@10: 0.10, F1@10: 0.10
# User ID: 86, Precision@10: 0.30, Recall@10: 0.21, F1@10: 0.25
# User ID: 181, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 26, Precision@10: 0.10, Recall@10: 0.25, F1@10: 0.14
# User ID: 61, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 265, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 59, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 507, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 426, Precision@10: 0.10, Recall@10: 0.06, F1@10: 0.07
# User ID: 453, Precision@10: 0.50, Recall@10: 0.08, F1@10: 0.14
# User ID: 373, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 121, Precision@10: 0.10, Recall@10: 0.08, F1@10: 0.09
# User ID: 90, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 144, Precision@10: 0.20, Recall@10: 0.08, F1@10: 0.11
# User ID: 137, Precision@10: 0.70, Recall@10: 0.25, F1@10: 0.37
# User ID: 321, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 589, Precision@10: 0.20, Recall@10: 0.25, F1@10: 0.22
# User ID: 352, Precision@10: 0.20, Recall@10: 0.03, F1@10: 0.06
# User ID: 231, Precision@10: 0.30, Recall@10: 0.60, F1@10: 0.40
# User ID: 602, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 76, Precision@10: 0.30, Recall@10: 0.12, F1@10: 0.18
# User ID: 494, Precision@10: 0.10, Recall@10: 0.25, F1@10: 0.14
# User ID: 499, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 233, Precision@10: 0.50, Recall@10: 0.17, F1@10: 0.25
# User ID: 78, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 110, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 271, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 584, Precision@10: 0.10, Recall@10: 0.06, F1@10: 0.07
# User ID: 537, Precision@10: 0.10, Recall@10: 0.11, F1@10: 0.11
# User ID: 272, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 79, Precision@10: 0.20, Recall@10: 0.15, F1@10: 0.17
# User ID: 319, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 295, Precision@10: 0.10, Recall@10: 0.12, F1@10: 0.11
# User ID: 33, Precision@10: 0.30, Recall@10: 0.10, F1@10: 0.15
# User ID: 362, Precision@10: 0.40, Recall@10: 0.18, F1@10: 0.25
# User ID: 476, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 238, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 456, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 133, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 131, Precision@10: 0.50, Recall@10: 0.36, F1@10: 0.42
# User ID: 353, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 552, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 247, Precision@10: 0.60, Recall@10: 0.20, F1@10: 0.30
# User ID: 277, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 245, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 44, Precision@10: 0.10, Recall@10: 0.10, F1@10: 0.10
# User ID: 193, Precision@10: 0.20, Recall@10: 0.29, F1@10: 0.24
# User ID: 183, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 205, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 375, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 506, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 189, Precision@10: 0.20, Recall@10: 0.50, F1@10: 0.29
# User ID: 108, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 204, Precision@10: 0.10, Recall@10: 0.06, F1@10: 0.07
# User ID: 168, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.07
# User ID: 101, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 170, Precision@10: 0.10, Recall@10: 0.10, F1@10: 0.10
# User ID: 409, Precision@10: 0.10, Recall@10: 0.04, F1@10: 0.06
# User ID: 180, Precision@10: 0.10, Recall@10: 0.20, F1@10: 0.13
# User ID: 285, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 423, Precision@10: 0.20, Recall@10: 0.40, F1@10: 0.27
# User ID: 376, Precision@10: 0.20, Recall@10: 0.07, F1@10: 0.11
# User ID: 513, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 5, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 520, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.04
# User ID: 56, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 220, Precision@10: 0.50, Recall@10: 0.12, F1@10: 0.20
# User ID: 393, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 165, Precision@10: 0.10, Recall@10: 0.08, F1@10: 0.09
# User ID: 609, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 48, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 310, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 263, Precision@10: 0.30, Recall@10: 0.07, F1@10: 0.12
# User ID: 35, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 541, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 273, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 227, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.07
# User ID: 116, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 497, Precision@10: 0.30, Recall@10: 0.30, F1@10: 0.30
# User ID: 118, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 379, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 230, Precision@10: 0.10, Recall@10: 0.04, F1@10: 0.05
# User ID: 301, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 478, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 398, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 171, Precision@10: 0.10, Recall@10: 0.06, F1@10: 0.08
# User ID: 282, Precision@10: 0.20, Recall@10: 0.04, F1@10: 0.07
# User ID: 93, Precision@10: 0.20, Recall@10: 0.11, F1@10: 0.14
# User ID: 436, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 80, Precision@10: 0.10, Recall@10: 0.03, F1@10: 0.05
# User ID: 251, Precision@10: 0.10, Recall@10: 0.20, F1@10: 0.13
# User ID: 164, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 40, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 569, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 455, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 403, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 394, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 34, Precision@10: 0.10, Recall@10: 0.06, F1@10: 0.07
# User ID: 161, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 501, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 585, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 523, Precision@10: 0.30, Recall@10: 0.20, F1@10: 0.24
# User ID: 542, Precision@10: 0.20, Recall@10: 0.09, F1@10: 0.12
# User ID: 159, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 242, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 559, Precision@10: 0.10, Recall@10: 0.04, F1@10: 0.05
# User ID: 413, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 67, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 102, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 308, Precision@10: 0.40, Recall@10: 0.17, F1@10: 0.24
# User ID: 402, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 345, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 218, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 85, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 565, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 579, Precision@10: 0.10, Recall@10: 0.07, F1@10: 0.08
# User ID: 46, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 450, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 136, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 53, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 384, Precision@10: 0.10, Recall@10: 0.07, F1@10: 0.08
# User ID: 112, Precision@10: 0.20, Recall@10: 0.15, F1@10: 0.17
# User ID: 162, Precision@10: 0.20, Recall@10: 0.25, F1@10: 0.22
# User ID: 407, Precision@10: 0.10, Recall@10: 0.25, F1@10: 0.14
# User ID: 493, Precision@10: 0.20, Recall@10: 0.17, F1@10: 0.18
# User ID: 311, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 550, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 15, Precision@10: 0.30, Recall@10: 0.11, F1@10: 0.16
# User ID: 69, Precision@10: 0.10, Recall@10: 0.11, F1@10: 0.11
# User ID: 203, Precision@10: 0.20, Recall@10: 0.22, F1@10: 0.21
# User ID: 71, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 39, Precision@10: 0.40, Recall@10: 0.20, F1@10: 0.27
# User ID: 261, Precision@10: 0.20, Recall@10: 0.18, F1@10: 0.19
# User ID: 533, Precision@10: 0.10, Recall@10: 0.12, F1@10: 0.11
# User ID: 444, Precision@10: 0.10, Recall@10: 0.12, F1@10: 0.11
# User ID: 253, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 36, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 149, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 269, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 442, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 430, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 283, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 574, Precision@10: 0.10, Recall@10: 0.20, F1@10: 0.13
# User ID: 281, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 496, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 236, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 366, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 526, Precision@10: 0.20, Recall@10: 0.17, F1@10: 0.18
# User ID: 377, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 99, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 237, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 196, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 124, Precision@10: 0.20, Recall@10: 0.20, F1@10: 0.20
# User ID: 540, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 511, Precision@10: 0.10, Recall@10: 0.10, F1@10: 0.10
# User ID: 461, Precision@10: 0.10, Recall@10: 0.20, F1@10: 0.13
# User ID: 128, Precision@10: 0.20, Recall@10: 0.29, F1@10: 0.24
# User ID: 340, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 531, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 446, Precision@10: 0.10, Recall@10: 0.06, F1@10: 0.07
# User ID: 37, Precision@10: 0.10, Recall@10: 0.25, F1@10: 0.14
# User ID: 297, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 38, Precision@10: 0.20, Recall@10: 0.12, F1@10: 0.15
# User ID: 138, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 303, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 173, Precision@10: 0.20, Recall@10: 0.40, F1@10: 0.27
# User ID: 445, Precision@10: 0.50, Recall@10: 0.33, F1@10: 0.40
# User ID: 81, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 278, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 324, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 293, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 558, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 258, Precision@10: 0.20, Recall@10: 0.40, F1@10: 0.27
# User ID: 481, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 416, Precision@10: 0.20, Recall@10: 0.20, F1@10: 0.20
# User ID: 515, Precision@10: 0.20, Recall@10: 0.40, F1@10: 0.27
# User ID: 9, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 358, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 457, Precision@10: 0.10, Recall@10: 0.10, F1@10: 0.10
# User ID: 486, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 498, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 194, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 244, Precision@10: 0.10, Recall@10: 0.05, F1@10: 0.07
# User ID: 338, Precision@10: 0.20, Recall@10: 0.25, F1@10: 0.22
# User ID: 383, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 94, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 150, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 447, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 390, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 386, Precision@10: 0.10, Recall@10: 0.07, F1@10: 0.08
# User ID: 581, Precision@10: 0.30, Recall@10: 0.38, F1@10: 0.33
# User ID: 389, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 299, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 374, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 72, Precision@10: 0.40, Recall@10: 0.44, F1@10: 0.42
# User ID: 441, Precision@10: 0.20, Recall@10: 0.22, F1@10: 0.21
# User ID: 502, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 208, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 468, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 598, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 571, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 397, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 127, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 329, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 355, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 2, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 65, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 276, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 529, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 439, Precision@10: 0.10, Recall@10: 0.25, F1@10: 0.14
# User ID: 142, Precision@10: 0.20, Recall@10: 0.25, F1@10: 0.22
# User ID: 556, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 289, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 163, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 396, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 250, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 296, Precision@10: 0.10, Recall@10: 0.20, F1@10: 0.13
# User ID: 87, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 291, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 30, Precision@10: 0.20, Recall@10: 0.29, F1@10: 0.24
# User ID: 576, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 545, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 433, Precision@10: 0.10, Recall@10: 0.25, F1@10: 0.14
# User ID: 322, Precision@10: 0.20, Recall@10: 0.10, F1@10: 0.13
# User ID: 333, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 548, Precision@10: 0.10, Recall@10: 0.20, F1@10: 0.13
# User ID: 337, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 188, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 435, Precision@10: 0.10, Recall@10: 0.12, F1@10: 0.11
# User ID: 360, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 147, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 471, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 302, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 431, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 518, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 349, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 519, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 114, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 214, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 243, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 343, Precision@10: 0.30, Recall@10: 0.25, F1@10: 0.27
# User ID: 421, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 3, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 145, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 97, Precision@10: 0.10, Recall@10: 0.14, F1@10: 0.12
# User ID: 300, Precision@10: 0.10, Recall@10: 0.17, F1@10: 0.12
# User ID: 568, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 55, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 60, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 320, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 347, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 175, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 172, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 487, Precision@10: 0.10, Recall@10: 0.09, F1@10: 0.10
# User ID: 530, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 535, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 472, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 549, Precision@10: 0.20, Recall@10: 0.50, F1@10: 0.29
# User ID: 155, Precision@10: 0.10, Recall@10: 0.11, F1@10: 0.11
# User ID: 77, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 364, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 192, Precision@10: 0.20, Recall@10: 0.50, F1@10: 0.29
# User ID: 207, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 467, Precision@10: 0.10, Recall@10: 0.25, F1@10: 0.14
# User ID: 49, Precision@10: 0.10, Recall@10: 0.25, F1@10: 0.14
# User ID: 505, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 120, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 157, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
# User ID: 485, Precision@10: 0.00, Recall@10: 0.00, F1@10: 0.00
